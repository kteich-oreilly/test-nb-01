# %% [markdown]
# This is a sample notebook for testing with BinderHub.

# %%
print("HI")

# %% [markdown]
# <a href="#section1">Section 1</a><br/>
# <a href="#section2">Section 2</a>

# %% [markdown]
# <a id='section1'></a>
# ## Section 1

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Phasellus blandit nisl non dui viverra, ut luctus lacus aliquam. Vivamus eu elementum felis. Duis tristique felis ac dapibus porta. Donec mauris neque, feugiat at magna a, sodales facilisis est. Nunc maximus sapien non sapien mattis, ut fermentum neque cursus. Suspendisse tincidunt auctor dictum. Donec consequat interdum arcu sed vehicula. Nam euismod efficitur venenatis. Ut et auctor leo, a egestas elit. Pellentesque eu mauris nec metus sodales fermentum eget a ante. Donec imperdiet diam nulla, quis malesuada leo sollicitudin rhoncus. Aliquam erat volutpat.
#
# Curabitur congue interdum semper. Nulla vitae orci risus. Mauris a ipsum non libero sagittis porttitor. Donec a consequat neque, vel tristique arcu. Nam posuere, eros nec ornare tristique, nulla lorem dignissim lorem, quis fermentum ligula orci at urna. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Suspendisse potenti. Integer maximus leo nec turpis mattis, vel ultricies lectus congue. Orci varius natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus.
#
# Vestibulum consectetur non enim non aliquam. Sed et eros pharetra, pulvinar nunc vel, gravida urna. Etiam ut enim consequat, dapibus risus at, consequat ipsum. Fusce et lacus ante. In molestie viverra diam. Pellentesque placerat semper ante in suscipit. Nunc elit elit, sollicitudin eu hendrerit in, gravida vel nibh. Aenean ultricies enim dolor, vel fringilla urna imperdiet id. Phasellus porta, dui at pretium viverra, eros magna dapibus nunc, quis pretium lorem libero eleifend diam. Vestibulum vitae pretium orci, sit amet tempus orci. Vestibulum rutrum nunc sed orci ullamcorper tristique. Mauris in posuere ipsum. Maecenas massa velit, blandit sit amet ligula ultricies, tristique placerat nunc.
#
# Phasellus posuere ligula sed purus malesuada vulputate. Orci varius natoque penatibus et magnis dis parturient montes, nascetur ridiculus mus. Duis egestas ullamcorper odio vel aliquet. Donec placerat vestibulum risus convallis iaculis. Integer consectetur bibendum ullamcorper. Nullam vitae ipsum dictum, porta libero id, cursus libero. Nam vulputate mi diam, quis rhoncus nibh egestas eget. Nulla non lectus ut metus finibus ornare sed quis nunc. Mauris feugiat in nibh eget vestibulum. Sed eleifend et lectus sit amet cursus. Etiam facilisis vehicula tortor, eu pharetra lectus faucibus eu. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Nam efficitur ligula vel tristique volutpat. Donec lobortis ligula vitae sapien accumsan, sed commodo elit blandit. Quisque accumsan dui non pellentesque vehicula. Cras lorem orci, faucibus ut consectetur a, congue nec nisl.
#
# Aenean sed sem vitae dolor aliquam auctor. Sed vestibulum ligula at nunc auctor pulvinar. Aliquam erat volutpat. Nulla vitae consequat justo. Vivamus et ultricies ante. Pellentesque pulvinar vel mi a dapibus. Vivamus vitae purus quis mauris blandit sollicitudin a consequat libero. Sed porttitor eget turpis ultrices ullamcorper. Pellentesque in dolor pulvinar, aliquam ante in, congue mi. Fusce convallis at leo eget condimentum. Cras ac diam aliquet, tempor enim cursus, tincidunt arcu. Phasellus cursus posuere nibh, nec tincidunt mauris lacinia et. Morbi sagittis finibus nibh et dignissim. Donec volutpat nisl a orci laoreet, non interdum quam laoreet.

# %%
class Graph:
    def __init__(self):
        # dictionary containing keys that map to the corresponding vertex object
        self.vertices = {}
 
    def add_vertex(self, key):
        """Add a vertex with the given key to the graph."""
        vertex = Vertex(key)
        self.vertices[key] = vertex
 
    def get_vertex(self, key):
        """Return vertex object with the corresponding key."""
        return self.vertices[key]
 
    def __contains__(self, key):
        return key in self.vertices
 
    def add_edge(self, src_key, dest_key, weight=1):
        """Add edge from src_key to dest_key with given weight."""
        self.vertices[src_key].add_neighbour(self.vertices[dest_key], weight)
 
    def does_edge_exist(self, src_key, dest_key):
        """Return True if there is an edge from src_key to dest_key."""
        return self.vertices[src_key].does_it_point_to(self.vertices[dest_key])
 
    def __iter__(self):
        return iter(self.vertices.values())
 
 
class Vertex:
    def __init__(self, key):
        self.key = key
        self.points_to = {}
 
    def get_key(self):
        """Return key corresponding to this vertex object."""
        return self.key
 
    def add_neighbour(self, dest, weight):
        """Make this vertex point to dest with given edge weight."""
        self.points_to[dest] = weight
 
    def get_neighbours(self):
        """Return all vertices pointed to by this vertex."""
        return self.points_to.keys()
 
    def get_weight(self, dest):
        """Get weight of edge from this vertex to dest."""
        return self.points_to[dest]
 
    def does_it_point_to(self, dest):
        """Return True if this vertex points to dest."""
        return dest in self.points_to
 
 
g = Graph()
print('Menu')
print('add vertex <key>')
print('add edge <src> <dest> [weight]')
print('display')
print('quit')
 
while True:
    do = input('What would you like to do? ').split()
 
    operation = do[0]
    if operation == 'add':
        suboperation = do[1]
        if suboperation == 'vertex':
            key = int(do[2])
            if key not in g:
                g.add_vertex(key)
            else:
                print('Vertex already exists.')
        elif suboperation == 'edge':
            src = int(do[2])
            dest = int(do[3])
            if src not in g:
                print('Vertex {} does not exist.'.format(src))
            elif dest not in g:
                print('Vertex {} does not exist.'.format(dest))
            else:
                if not g.does_edge_exist(src, dest):
                    if len(do) == 5:
                        weight = int(do[4])
                        g.add_edge(src, dest, weight)
                    else:
                        g.add_edge(src, dest)
                else:
                    print('Edge already exists.')
 
    elif operation == 'display':
        print('Vertices: ', end='')
        for v in g:
            print(v.get_key(), end=' ')
        print()
 
        print('Edges: ')
        for v in g:
            for dest in v.get_neighbours():
                w = v.get_weight(dest)
                print('(src={}, dest={}, weight={}) '.format(v.get_key(),
                                                             dest.get_key(), w))
        print()
 
    elif operation == 'quit':
        break

# %% [markdown]
# <a id='section2'></a>
# ## Section 2

# %%
class Graph:
    def __init__(self):
        # dictionary containing keys that map to the corresponding vertex object
        self.vertices = {}
 
    def add_vertex(self, key):
        """Add a vertex with the given key to the graph."""
        vertex = Vertex(key)
        self.vertices[key] = vertex
 
    def get_vertex(self, key):
        """Return vertex object with the corresponding key."""
        return self.vertices[key]
 
    def __contains__(self, key):
        return key in self.vertices
 
    def add_edge(self, src_key, dest_key, weight=1):
        """Add edge from src_key to dest_key with given weight."""
        self.vertices[src_key].add_neighbour(self.vertices[dest_key], weight)
 
    def does_vertex_exist(self, key):
        return key in self.vertices
 
    def does_edge_exist(self, src_key, dest_key):
        """Return True if there is an edge from src_key to dest_key."""
        return self.vertices[src_key].does_it_point_to(self.vertices[dest_key])
 
    def display(self):
        print('Vertices: ', end='')
        for v in self:
            print(v.get_key(), end=' ')
        print()
 
        print('Edges: ')
        for v in self:
            for dest in v.get_neighbours():
                w = v.get_weight(dest)
                print('(src={}, dest={}, weight={}) '.format(v.get_key(),
                                                             dest.get_key(), w))
 
    def __len__(self):
        return len(self.vertices)
 
    def __iter__(self):
        return iter(self.vertices.values())
 
 
class Vertex:
    def __init__(self, key):
        self.key = key
        self.points_to = {}
 
    def get_key(self):
        """Return key corresponding to this vertex object."""
        return self.key
 
    def add_neighbour(self, dest, weight):
        """Make this vertex point to dest with given edge weight."""
        self.points_to[dest] = weight
 
    def get_neighbours(self):
        """Return all vertices pointed to by this vertex."""
        return self.points_to.keys()
 
    def get_weight(self, dest):
        """Get weight of edge from this vertex to dest."""
        return self.points_to[dest]
 
    def does_it_point_to(self, dest):
        """Return True if this vertex points to dest."""
        return dest in self.points_to
 
 
def mst_krusal(g):
    """Return a minimum cost spanning tree of the connected graph g."""
    mst = Graph() # create new Graph object to hold the MST
 
    if len(g) == 1:
        u = next(iter(g)) # get the single vertex
        mst.add_vertex(u.get_key()) # add a copy of it to mst
        return mst
 
    # get all the edges in a list
    edges = []
    for v in g:
        for n in v.get_neighbours():
            # avoid adding two edges for each edge of the undirected graph
            if v.get_key() < n.get_key():
                edges.append((v, n))
 
    # sort edges
    edges.sort(key=lambda edge: edge[0].get_weight(edge[1]))
 
    # initially, each vertex is in its own component
    component = {}
    for i, v in enumerate(g):
        component[v] = i
 
    # next edge to try
    edge_index = 0
 
    # loop until mst has the same number of vertices as g
    while len(mst) < len(g):
        u, v = edges[edge_index]
        edge_index += 1
 
        # if adding edge (u, v) will not form a cycle
        if component[u] != component[v]:
 
            # add to mst
            if not mst.does_vertex_exist(u.get_key()):
                mst.add_vertex(u.get_key())
            if not mst.does_vertex_exist(v.get_key()):
                mst.add_vertex(v.get_key())
            mst.add_edge(u.get_key(), v.get_key(), u.get_weight(v))
            mst.add_edge(v.get_key(), u.get_key(), u.get_weight(v))
 
            # merge components of u and v
            for w in g:
                if component[w] == component[v]:
                    component[w] = component[u]
 
    return mst
 
 
g = Graph()
print('Undirected Graph')
print('Menu')
print('add vertex <key>')
print('add edge <src> <dest> <weight>')
print('mst')
print('display')
print('quit')
 
while True:
    do = input('What would you like to do? ').split()
 
    operation = do[0]
    if operation == 'add':
        suboperation = do[1]
        if suboperation == 'vertex':
            key = int(do[2])
            if key not in g:
                g.add_vertex(key)
            else:
                print('Vertex already exists.')
        elif suboperation == 'edge':
            src = int(do[2])
            dest = int(do[3])
            weight = int(do[4])
            if src not in g:
                print('Vertex {} does not exist.'.format(src))
            elif dest not in g:
                print('Vertex {} does not exist.'.format(dest))
            else:
                if not g.does_edge_exist(src, dest):
                    g.add_edge(src, dest, weight)
                    g.add_edge(dest, src, weight)
                else:
                    print('Edge already exists.')
 
    elif operation == 'mst':
        mst = mst_krusal(g)
        print('Minimum Spanning Tree:')
        mst.display()
        print()
 
    elif operation == 'display':
        g.display()
        print()
 
    elif operation == 'quit':
        break
